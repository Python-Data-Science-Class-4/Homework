# %% [markdown]
# Linear  Regression

# %%
from warnings import filterwarnings
filterwarnings('ignore')

import pandas as pd
insurance = pd.read_csv('insurance.csv')
df=insurance.copy()
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
df.isnull().values.any()
# Out:
# False

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
df2=df.copy()
df2
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df2['sex'] = df2['sex'].map({'female': 0, 'male': 1})

df2['smoker'] = df2['smoker'].map({'yes': 1, 'no': 0})

df2['region'] = df2['region'].map({'southwest': 0, 'southeast': 1, 'northwest': 2, 'northeast': 3})

print(df2.head())
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       0  16884.92400
# 1   18    1  33.770         1       0       1   1725.55230
# 2   28    1  33.000         3       0       1   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520

# %%
df2.corr()  # All cloumns'correlation including string ones.
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019 -0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185 -0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750 -0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673 -0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000  0.002181  0.787251
# region   -0.002127 -0.004588 -0.157566 -0.016569  0.002181  1.000000  0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251  0.006208  1.000000

# %%
import seaborn as sns
sns.pairplot(df, kind  ="reg");

# %%
import seaborn as sns
sns.pairplot(df2, kind  ="reg");

# %%
sns.jointplot(x = "age", y = "children", data = df, kind = "reg")

# %%
sns.jointplot(x = "bmi", y = "charges", data = df, kind = "reg")

# %%
sns.jointplot(x = "age", y = "charges", data = df, kind = "reg")

# %% [markdown]
# Simple Linear Regression

# %% [markdown]
# *Modelling

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df2[["bmi"]]
y = df2["charges"]
reg = LinearRegression()
model = reg.fit(X, y)
model.intercept_
# Out:
# 1192.9372089611497

# %%
model.coef_
# Out:
# array([393.8730308])

# %%
model.score(X,y)
# Out:
# 0.03933913991786264

# %%
# model denklemi= 1192.9 + 393.87*10
model.predict([[10]])
# Out:
# array([5131.66751694])

# %%
model.predict(X)[0:10]
# Out:
# array([12181.99476821, 14494.02945899, 14190.74722528, 10135.82437322,
#        12567.99033839, 11331.22902169, 14364.05135883, 12118.97508328,
#        12942.16971765, 11370.61632477])

# %%
y[0:10]
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# 5     3756.62160
# 6     8240.58960
# 7     7281.50560
# 8     6406.41070
# 9    28923.13692
# Name: charges, dtype: float64

# %%
new_bmi = [[20],[25],[30],[35]]
model.predict(new_bmi)
# Out:
# array([ 9070.39782491, 11039.7629789 , 13009.12813288, 14978.49328687])

# %%
model.predict([[32]])
# Out:
# array([13796.87419448])

# %% [markdown]
# Another Sample for Linear Regression

# %%
X = df[["age"]]
y = df["charges"]
reg = LinearRegression()
model = reg.fit(X, y)
model.intercept_
# Out:
# 3165.8850060630284

# %%
model.coef_
# Out:
# array([257.72261867])

# %%
LR_r2= model.score(X,y)
LR_r2
# Out:
# 0.08940589967885804

# %%
model.predict([[20]])
# Out:
# array([8320.3373794])

# %%
model.predict(X)[0:20]
# Out:
# array([ 8062.61476073,  7804.89214207, 10382.11832874, 11670.73142207,
#        11413.0088034 , 11155.28618474, 15021.12546474, 12701.62189674,
#        12701.62189674, 18629.24212608,  9608.95047274, 19144.68736341,
#         9093.5052354 , 17598.35165141, 10124.39571007,  8062.61476073,
#        16567.46117674,  9093.5052354 , 17598.35165141, 10897.56356607])

# %%
y[0:20]
# Out:
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 5      3756.62160
# 6      8240.58960
# 7      7281.50560
# 8      6406.41070
# 9     28923.13692
# 10     2721.32080
# 11    27808.72510
# 12     1826.84300
# 13    11090.71780
# 14    39611.75770
# 15     1837.23700
# 16    10797.33620
# 17     2395.17155
# 18    10602.38500
# 19    36837.46700
# Name: charges, dtype: float64

# %% [markdown]
# Error Detection

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
reg.predict(X)[0:10]
# Out:
# array([ 8062.61476073,  7804.89214207, 10382.11832874, 11670.73142207,
#        11413.0088034 , 11155.28618474, 15021.12546474, 12701.62189674,
#        12701.62189674, 18629.24212608])

# %%
y[0:10]
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# 5     3756.62160
# 6     8240.58960
# 7     7281.50560
# 8     6406.41070
# 9    28923.13692
# Name: charges, dtype: float64

# %%
k_t = pd.DataFrame({"real_y": y[0:10],
                   "guess_y": reg.predict(X)[0:10]})

k_t
# Out:
#         real_y       guess_y
# 0  16884.92400   8062.614761
# 1   1725.55230   7804.892142
# 2   4449.46200  10382.118329
# 3  21984.47061  11670.731422
# 4   3866.85520  11413.008803
# 5   3756.62160  11155.286185
# 6   8240.58960  15021.125465
# 7   7281.50560  12701.621897
# 8   6406.41070  12701.621897
# 9  28923.13692  18629.242126

# %%
k_t["error"] = k_t["real_y"] - k_t["guess_y"]
k_t
# Out:
#         real_y       guess_y         error
# 0  16884.92400   8062.614761   8822.309239
# 1   1725.55230   7804.892142  -6079.339842
# 2   4449.46200  10382.118329  -5932.656329
# 3  21984.47061  11670.731422  10313.739188
# 4   3866.85520  11413.008803  -7546.153603
# 5   3756.62160  11155.286185  -7398.664585
# 6   8240.58960  15021.125465  -6780.535865
# 7   7281.50560  12701.621897  -5420.116297
# 8   6406.41070  12701.621897  -6295.211197
# 9  28923.13692  18629.242126  10293.894794

# %%
k_t["error_square"] = k_t["error"]**2
k_t
# Out:
#         real_y       guess_y         error  error_square
# 0  16884.92400   8062.614761   8822.309239  7.783314e+07
# 1   1725.55230   7804.892142  -6079.339842  3.695837e+07
# 2   4449.46200  10382.118329  -5932.656329  3.519641e+07
# 3  21984.47061  11670.731422  10313.739188  1.063732e+08
# 4   3866.85520  11413.008803  -7546.153603  5.694443e+07
# 5   3756.62160  11155.286185  -7398.664585  5.474024e+07
# 6   8240.58960  15021.125465  -6780.535865  4.597567e+07
# 7   7281.50560  12701.621897  -5420.116297  2.937766e+07
# 8   6406.41070  12701.621897  -6295.211197  3.962968e+07
# 9  28923.13692  18629.242126  10293.894794  1.059643e+08

# %%
import numpy as np
np.sum(k_t["error_square"])
# Out:
# 588993093.5467993

# %%
np.mean(k_t["error_square"])
# Out:
# 58899309.35467993

# %%
LR_rmse=np.sqrt(np.mean(k_t["error_square"]))
LR_rmse
# Out:
# 7674.588546279203

# %% [markdown]
# Multiple Linear Regression¶

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict

# %%
X = df2.drop("charges", axis = 1)
y = df2["charges"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state= 42)

print("X_train", X_train.shape)
print("y_train",y_train.shape)
print("X_test",X_test.shape)
print("y_test",y_test.shape)
training = df2.copy()
print("training", training.shape)
# Out:
# X_train (1070, 6)
# y_train (1070,)
# X_test (268, 6)
# y_test (268,)
# training (1338, 7)

# %%
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %%
model.intercept_
# Out:
# -12760.459365293491

# %%
model.coef_
# Out:
# array([ 2.57056264e+02, -1.87914567e+01,  3.35781491e+02,  4.25091456e+02,
#         2.36478181e+04,  2.71284266e+02])

# %%
X_train
# Out:
#       age  sex     bmi  children  smoker  region
# 560    46    0  19.950         2       0       2
# 1285   47    0  24.320         0       0       3
# 1142   52    0  24.860         0       0       1
# 969    39    0  34.320         5       0       1
# 486    54    0  21.470         3       0       2
# ...   ...  ...     ...       ...     ...     ...
# 1095   18    0  31.350         4       0       3
# 1130   39    0  23.870         5       0       1
# 1294   58    1  25.175         0       0       3
# 860    37    0  47.600         2       1       0
# 1126   55    1  29.900         0       0       0
#
# [1070 rows x 6 columns]

# %%
new_data = [[60], [1],[30],[5],[1],[2]]
new_data = pd.DataFrame(new_data).T

# %%
model.predict(new_data)
# Out:
# array([39033.41363437])

# %%
df2.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       0  16884.92400
# 1   18    1  33.770         1       0       1   1725.55230
# 2   28    1  33.000         3       0       1   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520

# %%
MLR_rmse = np.sqrt(mean_squared_error(y_train, model.predict(X_train)))

# %%
MLR_rmse
# Out:
# 6105.789320191615

# %% [markdown]
# Model Tunning

# %%
X = df2.drop('charges', axis=1)
y = df2["charges"]
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=144)
lm = LinearRegression() 
model = lm.fit(X_train, y_train)

# %%
MLR_r2 = model.score(X_train, y_train)
MLR_r2
# Out:
# 0.7513733233356823

# %%
MLR_rmse = np.sqrt(-cross_val_score(model, 
                X_train, 
                y_train, 
                cv = 10, 
                scoring = "neg_mean_squared_error")).mean()
MLR_rmse
# Out:
# 6101.2505529905275

# %%
np.sqrt(-cross_val_score(model, 
                X_test, 
                y_test, 
                cv = 10, 
                scoring = "neg_mean_squared_error")).mean()
# Out:
# 5626.223721550143

# %% [markdown]
# PCR

# %% [markdown]
# Modelling

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
dms = pd.get_dummies(df[[ 'sex', 'smoker' ]])
dms.head()
# Out:
#    sex_female  sex_male  smoker_no  smoker_yes
# 0        True     False      False        True
# 1       False      True       True       False
# 2       False      True       True       False
# 3       False      True       True       False
# 4       False      True       True       False

# %%
y = df["charges"]

# %%
X_ = df.drop(["charges","sex","smoker","region"], axis = 1).astype("float64")

# %%
X_.head()
# Out:
#     age     bmi  children
# 0  19.0  27.900       0.0
# 1  18.0  33.770       1.0
# 2  28.0  33.000       3.0
# 3  33.0  22.705       0.0
# 4  32.0  28.880       0.0

# %%
X = pd.concat([X_, dms[["sex_female", "smoker_yes",]]], axis = 1)
X.head()
# Out:
#     age     bmi  children  sex_female  smoker_yes
# 0  19.0  27.900       0.0        True        True
# 1  18.0  33.770       1.0       False       False
# 2  28.0  33.000       3.0       False       False
# 3  33.0  22.705       0.0       False       False
# 4  32.0  28.880       0.0       False       False

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1338 non-null   float64
#  1   bmi         1338 non-null   float64
#  2   children    1338 non-null   float64
#  3   sex_female  1338 non-null   bool
#  4   smoker_yes  1338 non-null   bool
# dtypes: bool(2), float64(3)
# memory usage: 34.1 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)

print("X_train", X_train.shape)

print("y_train",y_train.shape)

print("X_test",X_test.shape)

print("y_test",y_test.shape)

training = df.copy()

print("training", training.shape)
# Out:
# X_train (1003, 5)
# y_train (1003,)
# X_test (335, 5)
# y_test (335,)
# training (1338, 7)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale 
pca = PCA()

# %%
X_reduced_train = pca.fit_transform(scale(X_train))

# %%
X_reduced_train[0:1,:]
# Out:
# array([[ 1.69127064, -0.32592751, -0.4601335 , -1.17249043, -0.11372038]])

# %%
X_reduced_train.shape
# Out:
# (1003, 5)

# %%
X_reduced_train[0:10,0]
# Out:
# array([ 1.69127064,  0.56568038, -1.50158738, -0.36893776, -0.58969431,
#        -0.79913374,  0.72820132,  0.39644162,  0.75252204,  1.08276016])

# %%
np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 4)*100)[0:5] # Verinin ½ kaçını ifade ediyor
# Out:
# array([ 22.56,  43.9 ,  63.77,  82.69, 100.  ])

# %%
lm = LinearRegression()
pcr_model = lm.fit(X_reduced_train, y_train)
pcr_model.intercept_
# Out:
# 13267.935817337988

# %%
pcr_model.coef_
# Out:
# array([-1751.90952852,  6768.0618618 , -2003.966619  ,  6545.22211802,
#        -3584.34393122])

# %% [markdown]
# Guess

# %%
y_pred = pcr_model.predict(X_reduced_train)
y_pred[0:5]
# Out:
# array([ 1754.57996913,  4533.44578628, 14466.05069057, 35868.37853991,
#         9996.9583838 ])

# %%
PCR_rmse= np.sqrt(mean_squared_error(y_train, y_pred))
PCR_rmse
# Out:
# 6092.54026520953

# %%
df["charges"].mean()
# Out:
# 13270.422265141257

# %%
PCR_r2= r2_score(y_train, y_pred)
PCR_r2
# Out:
# 0.7441660615416086

# %%
pca2 = PCA()
X_reduced_test = pca2.fit_transform(scale(X_test))
y_pred = pcr_model.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 15162.132176975787

# %% [markdown]
# Model Tuning

# %%
lm = LinearRegression()
pcr_model = lm.fit(X_reduced_train[:,0:10], y_train)
y_pred = pcr_model.predict(X_reduced_test[:,0:10])
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 15162.132176975787

# %%
from sklearn import model_selection

# %%
cv_10 = model_selection.KFold(n_splits = 10,
                             shuffle = True,
                             random_state = 1)

# %%
lm = LinearRegression()
RMSE = []

# %%
for i in np.arange(1, X_reduced_train.shape[1] + 1):
    
    score = np.sqrt(-1*model_selection.cross_val_score(lm, 
                                                       X_reduced_train[:,:i], 
                                                       y_train.ravel(), 
                                                       cv=cv_10, 
                                                       scoring='neg_mean_squared_error').mean())
    RMSE.append(score)

# %%
import matplotlib.pyplot as plt
plt.plot(RMSE, '-v')
plt.xlabel('Number of Components')
plt.ylabel('RMSE')
plt.title('PCR Model Tuning for Charges Guesses');

# %%
lm = LinearRegression()
pcr_model = lm.fit(X_reduced_train[:,:], y_train)
y_pred = pcr_model.predict(X_reduced_train[:,:])
print(np.sqrt(mean_squared_error(y_train, y_pred)))
# Out:
# 6092.54026520953

# %%
y_pred = pcr_model.predict(X_reduced_test[:,:])
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 15162.132176975787

# %% [markdown]
# PLS

# %% [markdown]
# Model

# %%
ms = pd.get_dummies(df[[ 'sex', 'smoker' ]])
y = df["charges"]
X_ = df.drop(['charges', 'sex', 'smoker', 'region'], axis=1).astype('float64')
X = pd.concat([X_, ms[['sex_female', 'smoker_yes']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
ms.head()
# Out:
#    sex_female  sex_male  smoker_no  smoker_yes
# 0        True     False      False        True
# 1       False      True       True       False
# 2       False      True       True       False
# 3       False      True       True       False
# 4       False      True       True       False

# %%
from sklearn.cross_decomposition import PLSRegression, PLSSVD

# %%
pls_model = PLSRegression().fit(X_train, y_train)

# %%
pls_model.coef_
# Out:
# array([[3605.18770478, 1987.93929008,  522.60978193,  -22.93389063,
#         9563.04171903]])

# %% [markdown]
# Guess

# %%
X_train.head()
# Out:
#        age     bmi  children  sex_female  smoker_yes
# 693   24.0  23.655       0.0       False       False
# 1297  28.0  26.510       2.0        True       False
# 634   51.0  39.700       1.0       False       False
# 1022  47.0  36.080       1.0       False        True
# 178   46.0  28.900       2.0        True       False

# %%
pls_model.predict(X_train)[0:10]
# Out:
# array([ 1767.64088953,  4560.5214102 , 14439.46826918, 35875.66418488,
#         9972.98809376, 12584.83456653,  4959.7398184 ,  4929.89261855,
#         4365.69251157,  2316.70011052])

# %%
y_train[0:10]
# Out:
# 693      2352.96845
# 1297     4340.44090
# 634      9391.34600
# 1022    42211.13820
# 178      8823.27900
# 287     14256.19280
# 1290     7133.90250
# 1113     5312.16985
# 294      3906.12700
# 471      2203.47185
# Name: charges, dtype: float64

# %%
y_pred = pls_model.predict(X_train)

# %%
PLS_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
PLS_rmse
# Out:
# 6092.746123675243

# %%
PLS_r2 = r2_score(y_train, y_pred)
PLS_r2
# Out:
# 0.74414877270329

# %%
y_pred = pls_model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 5950.599557128064

# %%
df["charges"].mean()
# Out:
# 13270.422265141257

# %% [markdown]
# Model Tunning

# %%
#CV
cv_10 = model_selection.KFold(n_splits=10, shuffle=True, random_state=1)


RMSE = []

for i in np.arange(1, X_train.shape[1] + 1):
    pls = PLSRegression(n_components=i)
    score = np.sqrt(-1*cross_val_score(pls, X_train, y_train, cv=cv_10, scoring='neg_mean_squared_error').mean())
    RMSE.append(score)

#Result Visualization
plt.plot(np.arange(1, X_train.shape[1] + 1), np.array(RMSE), '-v', c = "r")
plt.xlabel('Number of Components')
plt.ylabel('RMSE')
plt.title('Charges');

# %%
pls_model = PLSRegression(n_components = 2).fit(X_train, y_train)
y_pred = pls_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 5950.599557128064

# %% [markdown]
# Ridge Regresyon

# %% [markdown]
# Model

# %%
ms = pd.get_dummies(df[[ 'sex', 'smoker' ]])
y = df["charges"]
X_ = df.drop(['charges', 'sex', 'smoker', 'region'], axis=1).astype('float64')
X = pd.concat([X_, ms[['sex_female', 'smoker_yes']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
ms.head()
# Out:
#    sex_female  sex_male  smoker_no  smoker_yes
# 0        True     False      False        True
# 1       False      True       True       False
# 2       False      True       True       False
# 3       False      True       True       False
# 4       False      True       True       False

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha = 0.1).fit(X_train, y_train)
ridge_model
# Out:
# Ridge(alpha=0.1)

# %%
ridge_model.coef_
# Out:
# array([  260.01953979,   327.56182403,   434.9046627 ,   -66.67378202,
#        23613.74251879])

# %%
10**np.linspace(10,-2,100)*0.5
# Out:
# array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+07, 1.07721735e+07, 8.14875417e+06,
#        6.16423370e+06, 4.66301673e+06, 3.52740116e+06, 2.66834962e+06,
#        2.01850863e+06, 1.52692775e+06, 1.15506485e+06, 8.73764200e+05,
#        6.60970574e+05, 5.00000000e+05, 3.78231664e+05, 2.86118383e+05,
#        2.16438064e+05, 1.63727458e+05, 1.23853818e+05, 9.36908711e+04,
#        7.08737081e+04, 5.36133611e+04, 4.05565415e+04, 3.06795364e+04,
#        2.32079442e+04, 1.75559587e+04, 1.32804389e+04, 1.00461650e+04,
#        7.59955541e+03, 5.74878498e+03, 4.34874501e+03, 3.28966612e+03,
#        2.48851178e+03, 1.88246790e+03, 1.42401793e+03, 1.07721735e+03,
#        8.14875417e+02, 6.16423370e+02, 4.66301673e+02, 3.52740116e+02,
#        2.66834962e+02, 2.01850863e+02, 1.52692775e+02, 1.15506485e+02,
#        8.73764200e+01, 6.60970574e+01, 5.00000000e+01, 3.78231664e+01,
#        2.86118383e+01, 2.16438064e+01, 1.63727458e+01, 1.23853818e+01,
#        9.36908711e+00, 7.08737081e+00, 5.36133611e+00, 4.05565415e+00,
#        3.06795364e+00, 2.32079442e+00, 1.75559587e+00, 1.32804389e+00,
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03])

# %%
lambdas = 10**np.linspace(10,-2,100)*0.5 

ridge_model = Ridge()
coefficients = []

for i in lambdas:
    ridge_model.set_params(alpha = i)
    ridge_model.fit(X_train, y_train) 
    coefficients.append(ridge_model.coef_) 
    

    
ax = plt.gca()
ax.plot(lambdas, coefficients) 
ax.set_xscale('log') 

plt.xlabel('Lambda(Alpha) Values')
plt.ylabel('Coefficients/Weights')
plt.title('Ridge Coefficients as a Function of Regularization');

# %% [markdown]
# Guess

# %%
y_pred = ridge_model.predict(X_test)

# %%
RIDGE_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
RIDGE_rmse
# Out:
# 5952.163416811984

# %%
RIDGE_r2 = r2_score(y_test, y_pred)
RIDGE_r2
# Out:
# 0.7652065627590778

# %% [markdown]
# Model Tuning

# %%
lambdas = 10**np.linspace(10,-2,100)*0.5 
lambdas[0:5]
# Out:
# array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09])

# %%
from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(alphas = lambdas, 
                   scoring = "neg_mean_squared_error")

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        3.06795364e+00, 2.32079442e+00, 1.75559587e+00, 1.32804389e+00,
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         scoring='neg_mean_squared_error')

# %%
ridge_cv.alpha_
# Out:
# 0.18824679033962358

# %%
ridge_tuned = Ridge(alpha = ridge_cv.alpha_ 
                   ).fit(X_train,y_train)

# %%
np.sqrt(mean_squared_error(y_test, ridge_tuned.predict(X_test)))
# Out:
# 5952.71231491631

# %% [markdown]
# Lasso Regresyon

# %% [markdown]
# Model

# %%
ms = pd.get_dummies(df[[ 'sex', 'smoker' ]])
y = df["charges"]
X_ = df.drop(['charges', 'sex', 'smoker', 'region'], axis=1).astype('float64')
X = pd.concat([X_, ms[['sex_female', 'smoker_yes']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
ms.head()
# Out:
#    sex_female  sex_male  smoker_no  smoker_yes
# 0        True     False      False        True
# 1       False      True       True       False
# 2       False      True       True       False
# 3       False      True       True       False
# 4       False      True       True       False

# %%
X.head()
# Out:
#     age     bmi  children  sex_female  smoker_yes
# 0  19.0  27.900       0.0        True        True
# 1  18.0  33.770       1.0       False       False
# 2  28.0  33.000       3.0       False       False
# 3  33.0  22.705       0.0       False       False
# 4  32.0  28.880       0.0       False       False

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso(alpha = 0.1).fit(X_train, y_train)

# %%
lasso_model
# Out:
# Lasso(alpha=0.1)

# %%
lasso_model.coef_
# Out:
# array([  260.03564316,   327.55719128,   434.74241445,   -65.69665573,
#        23627.65513354])

# %%
lasso = Lasso()
lambdas = 10**np.linspace(10,-2,100)*0.5 
coefficients = []

for i in lambdas:
    lasso.set_params(alpha=i)
    lasso.fit(X_train, y_train)
    coefficients.append(lasso.coef_)
    
ax = plt.gca()
ax.plot(lambdas*2, coefficients)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
# Out:
# Text(0, 0.5, 'weights')

# %% [markdown]
# Guess

# %%
lasso_model.predict(X_test)
# Out:
# array([ 8.51702828e+03,  6.89423726e+03,  3.67759986e+04,  9.46421059e+03,
#         2.67893418e+04,  1.10935417e+04,  1.53146010e+01,  1.68237204e+04,
#         6.44149065e+02,  1.12089735e+04,  2.84907310e+04,  9.31630455e+03,
#         5.36788058e+03,  3.85309529e+04,  4.03988179e+04,  3.72392761e+04,
#         1.52910595e+04,  3.59821799e+04,  9.28404843e+03,  3.13152501e+04,
#         4.26860390e+03,  1.04947658e+04,  2.66379971e+03,  6.45888537e+03,
#         1.12166048e+04,  1.24461810e+04,  1.47990832e+04,  5.98261544e+03,
#         9.50386856e+03,  2.31859920e+03,  9.43750831e+03,  1.29462265e+04,
#         4.58235499e+03,  3.33974972e+03,  4.78776875e+03,  1.25054018e+04,
#         2.24268799e+03,  9.10992231e+03,  3.31878932e+04,  3.27190777e+04,
#         4.18221218e+03,  4.18982839e+03,  1.44229731e+04,  1.14470929e+04,
#         8.92621452e+03,  1.25500520e+04,  5.04566890e+03,  3.46444529e+03,
#         3.56610311e+04,  9.27089422e+03,  1.59722588e+04,  2.50112257e+03,
#         1.21032742e+04,  1.00345707e+03,  1.36051740e+04,  1.21545123e+04,
#         3.90605926e+03,  3.20230630e+04,  1.36238976e+04,  1.23728529e+04,
#         1.44982514e+04,  1.04945074e+04,  1.67566000e+04,  7.67468548e+03,
#         1.13348689e+04,  3.91062340e+03,  2.70109770e+04,  1.12389744e+04,
#         2.01027087e+03,  6.42467708e+03,  1.02174747e+04,  1.11109089e+04,
#         1.10988793e+04,  9.36945835e+03,  1.21085213e+04,  6.86148154e+03,
#         6.76402456e+03,  1.06635252e+04,  6.65955737e+03,  9.12373822e+03,
#         3.88357792e+03,  3.62593881e+04,  6.65151693e+03,  3.01891692e+04,
#         3.47715227e+04,  3.48193288e+04,  7.21166094e+03,  1.28030312e+04,
#         9.80179712e+03,  1.48400934e+04,  1.71696731e+04,  3.55001633e+04,
#         3.25411916e+04,  5.75129219e+03,  3.21191272e+04,  9.84367163e+03,
#         2.96251515e+04,  3.70978739e+03,  2.81810043e+04,  5.35654905e+03,
#         5.23976095e+03,  2.10676727e+03,  1.16142978e+04,  1.54564217e+04,
#         1.13759235e+04,  4.41078100e+03,  1.01291672e+04,  3.20208734e+04,
#        -5.21321651e+02,  3.30384824e+04,  3.54820413e+03,  1.02022891e+04,
#         1.38277121e+04,  3.10589222e+04,  1.09583865e+04,  4.21022646e+03,
#         1.27340203e+04,  3.21241368e+04,  8.27925234e+03,  3.14291084e+03,
#         7.86691811e+03,  1.04987860e+04,  1.46626705e+04,  5.75244019e+03,
#         3.66077128e+03,  1.00596742e+04,  1.09901006e+04,  1.07129038e+04,
#         1.45718033e+04,  7.47412555e+03,  5.49705734e+03,  9.41262143e+03,
#         9.41662044e+03,  1.19418182e+04,  8.58495318e+03,  1.56946010e+04,
#         7.89131331e+03,  3.21412518e+04,  3.55272633e+04,  3.10308715e+04,
#         5.86734546e+03,  1.20706072e+04,  6.12838631e+03,  1.43826091e+04,
#         2.69759706e+03,  3.33897344e+04,  6.20912761e+03,  5.29270642e+03,
#         1.41839007e+04,  7.29186813e+03,  3.84872168e+04,  2.89141523e+03,
#         5.92172830e+03,  3.11646703e+04,  1.13031415e+04,  7.96464135e+03,
#         1.44054552e+04,  9.97645957e+03,  2.71134382e+04,  3.29648941e+04,
#         1.40757470e+04,  1.50806674e+03,  1.36626140e+04,  1.77463043e+03,
#         5.76155107e+03,  1.17349421e+04,  4.00584940e+04,  3.63560561e+04,
#         3.35382677e+04,  4.12556119e+03,  7.85314432e+03,  8.92142843e+03,
#         1.18787260e+04,  4.75642698e+03,  2.29727125e+03,  3.23726849e+04,
#         2.54070504e+04,  1.76671801e+04,  2.63370213e+04,  1.01144946e+04,
#         3.67960244e+04, -8.96947689e+02,  6.83209575e+03,  8.01431885e+03,
#         3.98559493e+03,  4.86293720e+03,  5.44995509e+03,  4.57409071e+03,
#         1.52009968e+04,  1.11226628e+04,  7.20280271e+03,  1.93353428e+03,
#         1.01324706e+03,  3.22139548e+04,  1.66066395e+04,  1.21312052e+04,
#         1.10353361e+03,  1.20709485e+04,  9.99996285e+02,  9.08693347e+03,
#         1.74221030e+03,  3.38768572e+04,  1.09205170e+04,  2.50639274e+03,
#         2.57544326e+04,  2.64553452e+04,  9.41795145e+03,  1.69511564e+03,
#         1.33985160e+04,  1.44851029e+03,  1.08973176e+04,  1.08112827e+04,
#         1.62764858e+04,  2.70176633e+04,  7.21539750e+03,  4.64942887e+03,
#         5.97564766e+03,  1.34619340e+04,  1.13368037e+04,  8.44140866e+03,
#         4.86077860e+03,  1.21520124e+04,  1.39321660e+04,  3.59108832e+04,
#         4.00402944e+03,  2.90510488e+04, -6.11957420e+02,  2.72603558e+03,
#         1.12984865e+04,  1.57642001e+04,  5.29661488e+03,  6.87391232e+03,
#         4.16811261e+03,  3.16806616e+04,  7.22730177e+03,  1.25776129e+04,
#         5.50912371e+03,  9.85658111e+03,  3.63418080e+04,  4.54777437e+03,
#         9.30758691e+03,  3.14318378e+04,  5.49638804e+03,  4.69586752e+03,
#         9.52313385e+02,  4.70187474e+03,  4.85799282e+03,  6.83931840e+03,
#         1.87085514e+04, -1.56823920e+03,  2.59609294e+03,  1.10338057e+04,
#         3.43166076e+03,  9.80331524e+03,  3.49961447e+03,  5.19248899e+03,
#         1.28339253e+04,  6.07015515e+03,  7.88208055e+03,  7.05387595e+03,
#         8.80295601e+03,  1.04700426e+04,  2.79622935e+04,  3.92692664e+04,
#         1.16814834e+04,  7.26127102e+03,  4.08987535e+04,  1.25987034e+04,
#         7.06557760e+03,  7.88755334e+03,  9.36461244e+03,  1.12565522e+04,
#         1.00784921e+04,  1.77314261e+04,  1.38011112e+03,  2.31374514e+04,
#         1.21067350e+04,  3.26515562e+04,  4.81991280e+03,  1.33444535e+04,
#         1.02435827e+04,  1.72247927e+04,  1.03517111e+04,  1.13161454e+04,
#         3.25642172e+04,  2.85482451e+03,  1.37549803e+04,  3.94762679e+04,
#         5.05651414e+03,  5.93549989e+03,  2.83595434e+03,  1.17917726e+04,
#         2.50990789e+04,  1.36552893e+04,  9.60361521e+03,  9.68014570e+03,
#         1.36632855e+04,  1.38098874e+03,  2.60845058e+03,  3.07853157e+04,
#         3.03230124e+04,  1.36571820e+04,  3.52982375e+03,  2.52947723e+04,
#         1.37054202e+04,  3.08322153e+04,  2.92037456e+03,  3.91329578e+04,
#         1.12760650e+04,  4.91921808e+03,  7.17849617e+03,  2.71731032e+03,
#         2.57978851e+04,  1.46967958e+04,  9.65400161e+02,  1.31346007e+04,
#         1.28767316e+04,  1.47310409e+04,  3.51535413e+04,  1.42091523e+04,
#         3.18736965e+04,  1.03437403e+04,  1.84886329e+04,  6.28649139e+03,
#         9.17595456e+03,  9.73736404e+03,  1.55171683e+04,  9.54456628e+03,
#         7.73687923e+03,  1.52986447e+04,  1.23260264e+04,  1.42677327e+04,
#         7.78521403e+03,  2.62423213e+04,  9.41638901e+03])

# %%
y_pred = lasso_model.predict(X_test)

# %%
LASSO_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
LASSO_rmse
# Out:
# 5960.527902131975

# %%
LASSO_r2 = r2_score(y_test, y_pred)
LASSO_r2
# Out:
# 0.7645461957431352

# %% [markdown]
# Model Tuning

# %%
from sklearn.linear_model import LassoCV
lasso_cv_model = LassoCV(alphas = None, 
                         cv = 10, 
                         max_iter = 10000)

# %%
lasso_cv_model.fit(X_train,y_train)
# Out:
# LassoCV(cv=10, max_iter=10000)

# %%
lasso_cv_model.alpha_
# Out:
# 61.14507733769298

# %%
lasso_tuned = Lasso(alpha = lasso_cv_model.alpha_)

# %%
lasso_tuned.fit(X_train, y_train)
# Out:
# Lasso(alpha=61.14507733769298)

# %%
y_pred = lasso_tuned.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 5960.527902131975

# %% [markdown]
# ElasticNet Regresyonu

# %% [markdown]
# Model

# %%
ms = pd.get_dummies(df[[ 'sex', 'smoker' ]])
y = df["charges"]
X_ = df.drop(['charges', 'sex', 'smoker', 'region'], axis=1).astype('float64')
X = pd.concat([X_, ms[['sex_female', 'smoker_yes']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
X.head()
# Out:
#     age     bmi  children  sex_female  smoker_yes
# 0  19.0  27.900       0.0        True        True
# 1  18.0  33.770       1.0       False       False
# 2  28.0  33.000       3.0       False       False
# 3  33.0  22.705       0.0       False       False
# 4  32.0  28.880       0.0       False       False

# %%
from sklearn.linear_model import ElasticNet
enet_model = ElasticNet().fit(X_train, y_train)
enet_model.coef_
# Out:
# array([ 240.06981358,  326.39340656,  444.79331425, -281.36871177,
#        5803.46071436])

# %%
enet_model.intercept_
# Out:
# -7658.776699566559

# %% [markdown]
# Guess

# %%
enet_model
# Out:
# ElasticNet()

# %%
enet_model.predict(X_test)
# Out:
# array([11969.53683833, 10500.69794236, 22002.87010741, 13121.81291967,
#        13124.4880101 , 14950.66741768,  3969.9285953 , 20077.63344507,
#         4425.15136826, 14803.25094272, 14645.15748494, 13058.04659228,
#         9124.65339674, 24345.0361499 , 25904.89102588, 23027.31113287,
#        18643.33267442, 21547.1803377 , 12703.1943815 , 16961.40402223,
#         8367.73762791, 14194.23696662,  6824.90931777, 10333.4800354 ,
#        14575.90780279, 15690.16104824, 17920.45197359,  9798.4790574 ,
#        12914.78706983,  6499.97721848, 13005.14720098, 16131.30412638,
#         8482.65876046,  7107.87739962,  8819.63396446, 16136.45445951,
#         6162.89992118, 12586.81274289, 18667.61182364, 18721.03852872,
#         8179.99904547,  8299.98580899, 17633.44141811, 14815.31843258,
#        12821.67806147, 15925.95429621,  8967.51756484,  7327.33965024,
#        21542.43677533, 13203.21702762, 19032.3335022 ,  6693.44760969,
#        15626.65534568,  5189.50769116, 17022.85784865, 15714.79289247,
#         7853.29383876, 18145.89743002, 16787.52553332, 15636.1354764 ,
#        17563.56317269, 14225.61931528, 20102.66384826, 11187.31265034,
#        14620.88132225,  7691.61568219, 13353.6339055 , 14776.01948245,
#         5855.14079103, 10515.29875817, 14001.54524364, 14535.15967362,
#        14461.89788102, 13149.0954266 , 15771.62146574, 10468.05860171,
#        10793.0173625 , 13875.75502731, 10442.37841377, 12585.68669102,
#         8021.31181256, 21742.08444478, 10358.19876711, 16243.3538623 ,
#        21032.77854455, 20535.64485745, 11181.93749558, 16242.60694722,
#        13287.82488129, 18345.3020429 , 20267.7264819 , 20731.56778887,
#        18118.41760182,  9696.11987417, 18180.34546158, 13583.53997684,
#        15714.27261529,  7632.23327662, 14120.62568528,  9010.70597732,
#         8977.94702355,  6053.95049616, 15324.68420517, 18902.31478036,
#        14706.3179609 ,  8596.32116991, 13810.89537368, 17690.00633157,
#         3670.14638364, 18499.68987903,  7706.17151547, 14214.91697484,
#        17002.21149595, 16888.95981628, 14314.45782214,  8358.39530265,
#        16078.63157571, 17790.60787053, 11884.94124157,  7237.74593041,
#        11519.60233263, 14236.32678995, 17960.05046696,  9807.36638547,
#         7454.24677675, 13582.8695947 , 14460.31089652, 14285.75279769,
#        17713.02150066, 11541.97668155,  9184.6498749 , 13279.86843151,
#        13056.35225158, 15358.96776977, 12128.28105333, 19059.33099915,
#        11767.26276265, 18019.41838185, 21139.41028591, 16792.28745929,
#         9477.45461281, 15373.0474646 , 10143.89291374, 17680.98410436,
#         6744.33492469, 19153.36271657, 10114.24475409,  9000.06694043,
#        17513.61912156, 11143.45898996, 23952.2563312 ,  6759.64289337,
#        10090.3046906 , 17248.3216261 , 14867.44935591, 11821.2883345 ,
#        17706.04402692, 13374.10349174, 13231.52745212, 18889.81377214,
#        17260.96056847,  5468.97261273, 16950.94920591,  5862.73140747,
#         9870.27334993, 15449.04895507, 25292.74498574, 21717.71322538,
#        19384.98242211,  7951.32014682, 11220.24832799, 12475.15634562,
#        15626.25678672,  8693.19383471,  6186.6518051 , 18166.41502791,
#        11747.10783443, 20918.09646696, 12233.51483357, 13309.6331267 ,
#        22041.86665644,  3034.41911934, 10456.81681926, 11666.47936558,
#         7986.37538564,  8705.1182562 ,  9422.34177884,  8303.04635767,
#        18580.07832631, 14568.20877158, 11306.40433878,  5900.37493532,
#         4907.1896514 , 18324.51552228, 19899.40771898, 15433.43024481,
#         5065.87675563, 15339.45273184,  4970.15372663, 12419.0164755 ,
#         5557.39516949, 19558.43792434, 14866.02077427,  6691.25261672,
#        11869.90392085, 12423.43708195, 12964.76384659,  5621.4221217 ,
#        16969.26962551,  5295.37609879, 14210.3706427 , 14015.5411662 ,
#        19682.38369501, 13218.70474929, 10983.64583386,  8378.11684118,
#         9654.0933544 , 16641.88203711, 14470.47366629, 12073.00981651,
#         8760.09315603, 15803.36252506, 17745.27155273, 21779.80568078,
#         8103.25148372, 15206.78191474,  3344.88522174,  6886.92406501,
#        14831.17110616, 19137.98328099,  9410.28641722, 10194.81606958,
#         7940.74361228, 17541.422701  , 10527.90800403, 16132.24119746,
#         9550.02150945, 13554.17063437, 22012.33592457,  8645.0645386 ,
#        12448.46651267, 17583.26116988,  9317.27655326,  8512.15378016,
#         5119.50376851,  8722.44962819,  8647.21467771, 10749.64295577,
#        22026.34322261,  2607.90650506,  6522.49569433, 14800.08303784,
#         7202.75925805, 12999.55939047,  7453.44452459,  9026.05273573,
#        16178.18156471, 10097.46415113, 11453.39171447, 10789.76568534,
#        12361.25390873, 13587.75016131, 14140.93678258, 24722.2269064 ,
#        14852.01263244, 11055.84474947, 26301.39664118, 15910.86289972,
#        10504.20110265, 11281.02347437, 12657.62498181, 14848.36560257,
#        13365.67090351, 21001.15612587,  5272.75026674,  9504.61447163,
#        15846.00931021, 18634.71493574,  8710.92376566, 16888.91087473,
#        13590.59814528, 20261.37533764, 14029.35118554, 14856.21363758,
#        18578.32371117,  6901.00375984, 17063.03162487, 25161.14534352,
#         9011.25674634,  9970.7337485 ,  6799.58877038, 15196.85739873,
#        11095.18051291, 17271.51271786, 13302.95519619, 13149.85876034,
#        17237.24747429,  5209.05250581,  6496.72554133, 17011.05481396,
#        16359.97459845, 17421.58511842,  7495.14198175, 11646.82415973,
#        17088.81310489, 16943.53615715,  6845.62516682, 24567.36069805,
#        15144.13780888,  8875.45083608, 10837.77536834,  6908.86725802,
#        12022.3022545 , 17780.44412829,  5106.05566608, 16410.92138668,
#        16316.04546369, 17890.73524748, 21131.9597513 , 17431.97578739,
#        17638.56205474, 13877.52194194, 21790.45907968, 10236.86398796,
#        12595.48455734, 13401.44230821, 18886.67774908, 13007.31460255,
#        11549.8074541 , 18710.31176055, 15456.18175409, 17644.97860766,
#        11654.09401146, 12579.41102115, 13134.58444718])

# %%
y_pred = enet_model.predict(X_test)

# %%
EN_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
EN_rmse
# Out:
# 9535.755500376074

# %%
EN_r2 = r2_score(y_test, y_pred)
EN_r2
# Out:
# 0.39737592849395265

# %% [markdown]
# Model Tuning

# %%
from sklearn.linear_model import ElasticNetCV
enet_cv_model = ElasticNetCV(cv = 10, random_state = 0).fit(X_train, y_train)
enet_cv_model.alpha_
# Out:
# 99.19331475924518

# %%
enet_cv_model
# Out:
# ElasticNetCV(cv=10, random_state=0)

# %%
enet_tuned = ElasticNet(alpha = enet_cv_model.alpha_).fit(X_train,y_train)

# %%
y_pred = enet_tuned.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 11544.452662887159

# %%
model_names = ["LR", "MLR","PCR", "PLS",  "RIDGE", "LASSO", "EN"]
r2_scores = [LR_r2, MLR_r2, PCR_r2, PLS_r2, RIDGE_r2, LASSO_r2, EN_r2]
rmse_values = [LR_rmse, MLR_rmse, PCR_rmse, PLS_rmse, RIDGE_rmse, LASSO_rmse, EN_rmse]

# %%
# R2 Score Bar Chart
plt.figure(figsize=(10, 6))
bars = plt.bar(model_names, r2_scores, color='skyblue')
plt.xlabel('Models')
plt.ylabel('R2 Scores')
plt.title('R2 Score for Different Models')
plt.ylim(0, 1)  # Y-axis limit between 0 and 1 for R2 Score

# Adding text labels on top of each bar
for bar, r2_score in zip(bars, r2_scores):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, f'{r2_score:.2f}', ha='center', va='bottom')

plt.show()

# %%
# RMSE Bar Chart
plt.figure(figsize=(10, 6))
bars = plt.bar(model_names, rmse_values, color='salmon')
plt.xlabel('Models')
plt.ylabel('RMSE')
plt.title('Root Mean Squared Error (RMSE) for Different Models')

# Adding text labels on top of each bar
for bar, rmse_value in zip(bars, rmse_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 5, f'{rmse_value:.2f}', ha='center', va='bottom')

plt.show()
